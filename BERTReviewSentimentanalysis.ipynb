# %% [markdown]
# # Install & Import Dependencies

# %%
# !pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.10.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (0.11.1+cu111)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.7/dist-packages (0.10.0+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (3.10.0.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.19.5)

# %%
# !pip install transformers requests beautifulsoup4 pandas numpy
# Out:
# Collecting transformers
#   Downloading transformers-4.15.0-py3-none-any.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 7.5 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.19.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 4.5 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 56.7 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.10.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 51.5 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 68.4 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.7.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.4.0 pyyaml-6.0 sacremoses-0.0.47 tokenizers-0.10.3 transformers-4.15.0

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np

#AutoTokenizer allows to pass string and convert to sequence of numbers that we can then pass to NLP model
#AutoModelSequenceClassification gives architecture from transformers that we will be able to load in our NLP model
#argmax from torch will give us highest sequqnce result
#requests will help to grab data from Yelp web page
#BeautifulSoup allows to extract data from scraped web page
#re will help to form regex function to extract certain comments

# %% [markdown]
# # Instantiate Model

# %%
tokenizer = AutoTokenizer.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')

model = AutoModelForSequenceClassification.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')
# Out:
# Downloading:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/953 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/851k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/638M [00:00<?, ?B/s]

# %% [markdown]
# #Encode and Calculate Sentiment

# %%
tokens = tokenizer.encode('I hated that, absolutely waste',return_tensors='pt')
#pt means pytorch

# %%
tokens
# Out:
# tensor([[  101,   151, 39487, 10163, 10203,   117, 35925, 10563, 43346,   102]])

# %%
tokenizer.decode(tokens[0])
# Out:
# '[CLS] i hated that, absolutely waste [SEP]'

# %%
result = model(tokens)

# %%
result
#the values in tensor represent score of the comment for diff sentiment classes
# Out:
# SequenceClassifierOutput([('logits',
#                            tensor([[ 4.1835,  2.3260, -0.2570, -2.6977, -2.7281]],
#                                   grad_fn=<AddmmBackward0>))])

# %%
# to get highest value results

int(torch.argmax(result.logits))+1
# Out:
# 1

# %% [markdown]
# # Collect Reviews

# %%
r = requests.get('https://www.yelp.com/biz/the-farmers-kitchen-farmington?osq=Restaurants')
soup = BeautifulSoup(r.text,'html.parser')
regex = re.compile('.*comment.*') #get all has commment class
results = soup.find_all('p',{'class':regex}) 
reviews = [result.text for result in results]

# %%
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '<!DOCTYPE html><html lang="en-US" prefix="og: http://ogp.me/ns#" style="margin: 0;padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;"><head><script>document.documentElement.className=document.documentElement.className.replace(/\x08no-js\x08/,"js");</script><meta http-equiv="Content-Type" content="text/html; charset=UTF-8" /><meta http-equiv="Content-Language" content="en-US" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><link rel="mask-icon" sizes="any" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b2bb2fb0ec9c/assets/img/logos/yelp_burst.svg" content="#FF1A1A"><link rel="shortcut icon" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b05852393ae5/assets/img/logos/favicon.ico"><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script async src="https://www.google-analytics.com/analytics.js"></script><meta id="emotion-container"><style data-emotion-css="0 xl0fej swh6wo 16s2nge rtcdlu 110vchp tza3mu 1enow5j zbyz55 1clzr6h 1kfrpc3 79elbk 1gfwrmo 1ez3qjc vyw8yh rigrq3 12y3mxl 1k57hak ralh0w wonnhn s36a9t 9dhnpo 1lwccx4 xlzvdl 1iikwpv 1422juy 1sufhje 1mrxdyn 1bwnp89 1e4fdj9 gsky inq9gi 1c2abjj 1rw3tz3 1xfj5g9 12bvu5l 1yh9ujw 1afdtvl 1nx1n9o 3jhitf tvj4j5 ye4fzl dh50jt jtkdlu 1d56pvc 15j7fnr war30n 1nr3v5i wo0tt2 1lr1m88 tjgdvq ollt2v 1pxws0l 1kq79li lf8rwb ivlxj9 12anxc3 1k09l3a 15dvgpy 1peqmen 19makd2 1nv8jdk ypchpq sqf6pb ki5pzg v7ja7z kuk3f8 1dtm47l qyxsyq 1r00jhk hx4bzs avspch 11gvbtp 1cuazig 9t8tgp 53c188 fksa8h nyitw0 19sk4h4 5588ua 1x9iesk 1yy09vp 1ec998h vfk6og oyv5ea w11kp 1ejjr07 1rblj0d 18es1no 1h7ysrc mpwjkl hvzf3i 10y60kr 1bp797t 44o0z1 1t7f977 18fyvmz rzgor1 1ccncw 1wayfxy 106vfgv aso7zu 1p80smk xp8w2v 1vhakgw s62wli d0sgb6">html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block;}body{line-height:1;}ol,ul{list-style:none;}blockquote,q{quotes:none;}blockquote:before,blockquote:after,q:before,q:after{content:\'\';content:none;}table{border-collapse:collapse;border-spacing:0;}.hidden-non-responsive-inline,.hidden-non-responsive-inline-block,.hidden-non-responsive-block,.hidden-non-responsive-table-cell{display:none !important;}@media only screen and (max-width:599px){.responsive .responsive-small-display-inline-block{display:inline-block !important;}.responsive .responsive-small-display-block{display:block !important;}.responsive .responsive-small-display-inline{display:inline !important;}}@media only screen and (max-width:780px){.responsive-biz .responsive-small-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-small-display-block{display:block !important;}.responsive-biz .responsive-small-display-inline{display:inline !important;}}@media only screen and (max-width:1023px){.responsive .responsive-medium-display-inline-block{display:inline-block !important;}.responsive .responsive-medium-display-block{display:block !important;}.responsive .responsive-medium-display-inline{display:inline !important;}}@media only screen and (max-width:1240px){.responsive-biz .responsive-medium-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-medium-display-block{display:block !important;}.responsive-biz .responsive-medium-display-inline{display:inline !important;}}@media only screen and (max-width:1143px){.responsive .responsive-desktop-small-display-i ...

# %%
soup
# Out:
# <!DOCTYPE html>
# /,"js");</script><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="en-US" http-equiv="Content-Language"/><meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/><link content="#FF1A1A" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b2bb2fb0ec9c/assets/img/logos/yelp_burst.svg" rel="mask-icon" sizes="any"/><link href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b05852393ae5/assets/img/logos/favicon.ico" rel="shortcut icon"/><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script async="" src="https://www.google-analytics.com/analytics.js"></script><meta id="emotion-container"/><style data-emotion-css="0 xl0fej swh6wo 16s2nge rtcdlu 110vchp tza3mu 1enow5j zbyz55 1clzr6h 1kfrpc3 79elbk 1gfwrmo 1ez3qjc vyw8yh rigrq3 12y3mxl 1k57hak ralh0w wonnhn s36a9t 9dhnpo 1lwccx4 xlzvdl 1iikwpv 1422juy 1sufhje 1mrxdyn 1bwnp89 1e4fdj9 gsky inq9gi 1c2abjj 1rw3tz3 1xfj5g9 12bvu5l 1yh9ujw 1afdtvl 1nx1n9o 3jhitf tvj4j5 ye4fzl dh50jt jtkdlu 1d56pvc 15j7fnr war30n 1nr3v5i wo0tt2 1lr1m88 tjgdvq ollt2v 1pxws0l 1kq79li lf8rwb ivlxj9 12anxc3 1k09l3a 15dvgpy 1peqmen 19makd2 1nv8jdk ypchpq sqf6pb ki5pzg v7ja7z kuk3f8 1dtm47l qyxsyq 1r00jhk hx4bzs avspch 11gvbtp 1cuazig 9t8tgp 53c188 fksa8h nyitw0 19sk4h4 5588ua 1x9iesk 1yy09vp 1ec998h vfk6og oyv5ea w11kp 1ejjr07 1rblj0d 18es1no 1h7ysrc mpwjkl hvzf3i 10y60kr 1bp797t 44o0z1 1t7f977 18fyvmz rzgor1 1ccncw 1wayfxy 106vfgv aso7zu 1p80smk xp8w2v 1vhakgw s62wli d0sgb6">html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block;}body{line-height:1;}ol,ul{list-style:none;}blockquote,q{quotes:none;}blockquote:before,blockquote:after,q:before,q:after{content:'';content:none;}table{border-collapse:collapse;border-spacing:0;}.hidden-non-responsive-inline,.hidden-non-responsive-inline-block,.hidden-non-responsive-block,.hidden-non-responsive-table-cell{display:none !important;}@media only screen and (max-width:599px){.responsive .responsive-small-display-inline-block{display:inline-block !important;}.responsive .responsive-small-display-block{display:block !important;}.responsive .responsive-small-display-inline{display:inline !important;}}@media only screen and (max-width:780px){.responsive-biz .responsive-small-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-small-display-block{display:block !important;}.responsive-biz .responsive-small-display-inline{display:inline !important;}}@media only screen and (max-width:1023px){.responsive .responsive-medium-display-inline-block{display:inline-block !important;}.responsive .responsive-medium-display-block{display:block !important;}.responsive .responsive-medium-display-inline{display:inline !important;}}@media only screen and (max-width:1240px){.responsive-biz .responsive-medium-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-medium-display-block{display:block !important;}.responsive-biz .responsive-medium-display-inline{display:inline !important;}}@media only screen and (max-width:1143px){.responsive .responsive-desktop-small-display-inline-block{display:inline-block !important;}.responsive .responsive-desktop-small-display-block{display:block !important;}.responsive .responsive-desktop-small-display-inline{display:inline !important;}}@media only screen and (max-width:1143px){.responsive-biz .respo ...
# <script>!function(n){"use strict";n.loadCSS||(n.loadCSS=function(){});var o=loadCSS.relpreload={};if(o.support=function(){var e;try{e=n.document.createElement("link").relList.supports("preload")}catch(t){e=!1}return function(){return e}}(),o.bindMediaToggle=function(t){var e=t.media||"all";function a(){t.addEventListener?t.removeEventListener("load",a):t.attachEvent&&t.detachEvent("onload",a),t.setAttribute("onload",null),t.media=e}t.addEventListener?t.addEventListener("load",a):t.attachEvent&&t.attachEvent("onload",a),setTimeout(function(){t.rel="stylesheet",t.media="only x"}),setTimeout(a,3e3)},o.poly=function(){if(!o.support())for(var t=n.document.getElementsByTagName("link"),e=0;e<t.length;e++){var a=t[e];"preload"!==a.rel||"style"!==a.getAttribute("as")||a.getAttribute("data-loadcss")||(a.setAttribute("data-loadcss",!0),o.bindMediaToggle(a))}},!o.support()){o.poly();var t=n.setInterval(o.poly,500);n.addEventListener?n.addEventListener("load",function(){o.poly(),n.clearInterval(t)}):n.attachEvent&&n.attachEvent("onload",function(){o.poly(),n.clearInterval(t)})}"undefined"!=typeof exports?exports.loadCSS=loadCSS:n.loadCSS=loadCSS}("undefined"!=typeof global?global:this);</script>
# <script>
#         window.yelp = window.yelp || {};
#         window.yelp.critical_css = window.yelp.critical_css || {};
#         window.yelp.critical_css.css_map = {};
#     </script>
# <!-- css-middleware: bootstrap placeholder --><script>(function() { window.yelp.critical_css.recordDone=function(c,l){l.onload=null;var i=window.yelp.critical_css.css_map[c];window.yelp.critical_css.css_map[c]=i&&Object.keys(i).length?i:{loaded:!1,linkTag:l}}; })()</script>
# <meta name="critical_css_middleware"/><link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-shared-9ec66716ce9b4747d5dded4f415e0ebf09731f9d-pkg.yji-2b605ccf423ba7f32f70.css" rel="stylesheet"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-shared-f3d9768dda657b2dfc6d020a6f3b055aef2798af-pkg.yji-ae60ff1d2d396ede3a88.css" rel="stylesheet"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-shared-35fd38d19f6b8e4e03a764b376f2f0ad29c24576-pkg.yji-6e9f62b628d83dd09325.css" rel="stylesheet"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-shared-23d073af1d0eccc69be2959e7a90c6e0d376b125-pkg.yji-ae29812700db4a14c85b.css" rel="stylesheet"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-shared-6d9bc2bab3f05eea3b9e60a2c382524de9a960b4-pkg.yji-1e9c0fd681a2c63dc174.css" rel="stylesheet"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-shared-517f09ffa454b877f1d19433ac56582c832ce3d8-pkg.yji-2952105466568101c56a.css" rel="stylesheet"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-gondola-biz-details-pkg.yji-16b34327194d862158f1.css" rel="stylesheet"/><link as="style" data-chunk="components-RelatedBusinessesCarousel" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-RelatedBusinessesCarousel.yji-b558c66f19934bdbfe7a.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-ReviewFeedWarEditor" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-ReviewFeedWarEditor.yji-e825e6c201ea4aad3643.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-BizQuestionsGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizQuestionsGQL.yji-f99580137c641aaab850.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-ServiceUpdateSummaryGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-ServiceUpdateSummaryGQL.yji-456daedc5567db2c2247.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-MoreBusinessInfo" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-MoreBusinessInfo.yji-2b847120a4c94e3ba1f2.chunk.css" rel="preload"/>
# <link as="style" data-chunk="BizHoursGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/BizHoursGQL.yji-dad5e49120422e2e9d29.chunk.css" rel="preload"/>
# <link as="style" data-chunk="MapBoxV2GQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/MapBoxV2GQL.yji-4881c82d23ae7af43e76.chunk.css" rel="preload"/>
# <link as="style" data-chunk="OnTheMenuGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/OnTheMenuGQL.yji
="/opensearch" rel="search" title="Yelp" type="application/opensearchdescription+xml"/><link data-rh="true" href="https://www.facebook.com/yelp" id="sitelink-profile-facebook" itemprop="sameAs"/><link data-rh="true" href="https://twitter.com/yelp" id="sitelink-profile-twitter" itemprop="sameAs"/><link data-rh="true" href="https://www.linkedin.com/company/31517" id="sitelink-profile-linkedin" itemprop="sameAs"/><link data-rh="true" href="https://instagram.com/yelp" id="sitelink-profile-instagram" itemprop="sameAs"/><link data-rh="true" href="https://www.yelp.com" id="sitelink" itemprop="url"/><link data-rh="true" href="https://www.yelp.com/biz/the-farmers-kitchen-farmington" rel="canonical"/><link data-rh="true" href="android-app://com.yelp.android/yelp-app-indexing/biz/mvSk1Ev6-3FL-hT2Yh7HQQ?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=google" rel="alternate"/><link data-rh="true" href="ios-app://284910350/yelp//biz/mvSk1Ev6-3FL-hT2Yh7HQQ?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=google" rel="alternate"/><script data-rh="true">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-THHF2RF');</script><script data-rh="true">!function(n,e){var t,o,i,c=[],f={passive:!0,capture:!0},r=new Date,a="pointerup",u="pointercancel";function p(n,c){t||(t=c,o=n,i=new Date,w(e),s())}function s(){o>=0&&o<i-r&&(c.forEach(function(n){n(o,t)}),c=[])}function l(t){if(t.cancelable){var o=(t.timeStamp>1e12?new Date:performance.now())-t.timeStamp;"pointerdown"==t.type?function(t,o){function i(){p(t,o),r()}function c(){r()}function r(){e(a,i,f),e(u,c,f)}n(a,i,f),n(u,c,f)}(o,t):p(o,t)}}function w(n){["click","mousedown","keydown","touchstart","pointerdown"].forEach(function(e){n(e,l,f)})}w(n),self.perfMetrics=self.perfMetrics||{},self.perfMetrics.onFirstInputDelay=function(n){c.push(n),s()}}(addEventListener,removeEventListener);</script><title data-rh="true">THE FARMER’S KITCHEN - 69 Photos &amp; 148 Reviews - American (Traditional) - 444 NH Route 11, Farmington, NH - Restaurant Reviews - Phone Number</title><meta content="Delivery &amp; Pickup Options - 148 reviews of The Farmer's Kitchen &quot;VERY good breakfast.  My husband loves the eggs benedict.  says it's the best in NH.  Wish they would serve waffles with strawberries, my favorite.&quot;" data-rh="true" name="description"/><meta content="mvSk1Ev6-3FL-hT2Yh7HQQ" data-rh="true" name="yelp-biz-id"/><meta content="Yelp,recommendation,San Francisco, bay area, local,business,review,friend,restaurant,dentist,doctor,salon,spa,shopping,store,share,community,massage,sushi,pizza,nails,New York,Los Angeles" data-rh="true" name="keywords"/><meta content="Yelp" data-rh="true" property="og:site_name"/><meta content="yelpyelp:business" data-rh="true" property="og:type"/><meta content="https://s3-media0.fl.yelpcdn.com/bphoto/bsSZ9iaNBQpntHynKkDdLA/o.jpg" data-rh="true" property="og:image"/><meta content="1190" data-rh="true" property="og:image:height"/><meta content="2000" data-rh="true" property="og:image:width"/><meta content="The Farmer's Kitchen - Farmington, NH" data-rh="true" property="og:title"/><meta content="https://www.yelp.com/biz/the-farmers-kitchen-farmington?osq=Restaurants" data-rh="true" property="og:url"/><meta content="" data-rh="true" property="og:description"/><meta content="97534753161" data-rh="true" property="fb:app_id"/> ...
# <script>document.cookie = "xcj=1|NzXXgdSNnaB3b9-WDNCfiTM2ANdoljfo77zUsH4l6Tk; Domain=.yelp.com; expires=Tue, 19 Apr 2022 18:19:29 GMT; Max-Age=7776000; Path=/";</script><link href="/opensearch" rel="search" title="Yelp" type="application/opensearchdescription+xml"/></head><body class="" style="margin: 0; padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline; line-height: 1;"><noscript></noscript><yelp-react-root><div data-hypernova-id="058dab79-28b6-4a40-ab73-bbbfceebbd22" data-hypernova-key="yelpfrontend__0260__yelpfrontend__GondolaBizDetails__dynamic"><div class=" toast-list__09f24__miHvH border-color--default__09f24__NPAKY"></div><span class=""><!-- <a href="/biz/outlook-autumn-market-fundamental-catwalk-flimsy-roost-legibility-individualism-grocer-predestination-2">yelp</a> --></span><div class=" border-color--default__09f24__NPAKY" data-lcp-target-id="CONSUMER_HEADER"><div class=" css-fksa8h padding-t1-5__09f24__VNyRg padding-b1-5__09f24__M_AcV border-color--default__09f24__NPAKY background-color--gray-extra-light__09f24__UbDJH"><div class=" a11y-menu-container__09f24__V3Frf border-color--default__09f24__NPAKY"></div></div><div class=" consumer-header-container__09f24__ieW2P border--bottom__09f24___mg5X border-color--default__09f24__NPAKY background-color--white__09f24__ulvSM"><div class=" consumer-header__09f24__GAvyT border-color--default__09f24__NPAKY"><div class=" arrange__09f24__LDfbs vertical-align-middle__09f24__zU9sE border-color--default__09f24__NPAKY"><div class=" logo-arrange-unit__09f24__Rbwi3 arrange-unit__09f24__rqHTg border-color--default__09f24__NPAKY"><div class=" margin-r4__09f24__mJ91T margin-sm-r0__09f24__WfNsG border-color--default__09f24__NPAKY"><div class=" logo__09f24__ip022 logo-image__09f24__SXMH_ logo-container__09f24__jaSQB border-color--default__09f24__NPAKY" data-analytics-label="logo" id="logo" style="background-image:url(https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_design_cdn/7ef71bf77a33/assets/img/brand/logo_desktop.svg)"><a class="logo-link__09f24__fS20h css-1lwccx4" href="/" role="link">Yelp</a></div></div></div><div class=" search-suggest-arrange-unit__09f24__zqa_F arrange-unit__09f24__rqHTg arrange-unit-fill__09f24__CUubG border-color--default__09f24__NPAKY"><div class=" search-suggest-container-outer__09f24__SUL4j border-color--default__09f24__NPAKY"><div class=" search-suggest-container-inner__09f24__WsMGR border-color--default__09f24__NPAKY"><div class=" arrange__09f24__LDfbs gutter-2__09f24__CCmUo border-color--default__09f24__NPAKY"><div class=" arrange-unit__09f24__rqHTg arrange-unit-fill__09f24__CUubG border-color--default__09f24__NPAKY"><div class=" search-suggest__09f24__Yd8a9"><div class=""><form action="/search" class=" find-near-form__09f24__qHR1I" id="header_find_form" method="get" role="search"><div class=" undefined arrange__09f24__LDfbs border-color--default__09f24__NPAKY"><div class=" arrange-unit__09f24__rqHTg arrange-unit-fill__09f24__CUubG border-color--default__09f24__NPAKY"><div class=" find-near-arrange__09f24__czL3z find-near-arrange--height__09f24__uFYD6 arrange__09f24__LDfbs layout-equal__09f24__odeM0 border-color--default__09f24__NPAKY"><div class=" find-near-arrange-unit__09f24__hvHOu arrange-unit__09f24__rqHTg border-color--default__09f24__NPAKY"><label class=" label__09f24__2EYit pseudo-input__09f24__nfxxT pseudo-input--find-near__09f24__o_Lff pseudo-input--find__09f24__dWbac pseudo-input__09f24__bK86t" for="search_description"><span class=" pseudo-input-text__09f24__PW2ow display--inline__09f24__c6N_k border-color--default__09f24__NPAKY"><div class=" pseudo-input-icon-container__09f24__WCnQN margin-r1-5__09f24__ot4bd border-color--default__09f24__NPAKY"><span aria-hidden="false" aria-label="Find" class="icon--24-search-v2 pseudo-input-icon__09f24__b1eFr css-nyitw0" role="img"><svg class="icon_svg" height="24" width="24"><path d="M21.853 20.355l-3.444-3.443a9.428 9.428 0 10-16.761-6.171 9.428 9.428 0 0015.348 7.586l3.443 3.4 ...
# <script data-hypernova-id="058dab79-28b6-4a40-ab73-bbbfceebbd22" data-hypernova-key="yelpfrontend__0260__yelpfrontend__GondolaBizDetails__dynamic" type="application/json"><!--{"locale":"en_US","messages":{"Photo of %{businessName} - %{location}. %{caption}":"Photo of %{businessName} - %{location}. %{caption}","Located in:":"Located in:","Services Offered":"Services Offered","Saskatchewan":"Saskatchewan","Report Answer":"Report Answer","Edit and confirm":"Edit and confirm","Iowa":"Iowa","Please refer to our ":"Please refer to our ","Yes, allow notifications":"Yes, allow notifications","There are more restaurants on Yelp that deliver to your address":"There are more restaurants on Yelp that deliver to your address","Forgot Password":"Forgot Password","Call %{phone_number}":"Call %{phone_number}","Remove Review":"Remove Review","Warning":"Warning","Your review has not been posted yet! To post it you must first confirm your email address.":"Your review has not been posted yet! To post it you must first confirm your email address.","Argentina":"Argentina","%{smart_count} person found this helpful||||%{smart_count} people found this helpful":"%{smart_count} person found this helpful||||%{smart_count} people found this helpful","Submit request":"Submit request","My review on #Yelp":"My review on #Yelp","Belgium":"Belgium","Request a Virtual Consultation":"Request a Virtual Consultation","Your Name":"Your Name","By continuing, you agree to Yelp’s <0&gt;Terms of Service</0&gt; and acknowledge Yelp’s <1&gt;Privacy Policy</1&gt;.":"By continuing, you agree to Yelp’s <0&gt;Terms of Service</0&gt; and acknowledge Yelp’s <1&gt;Privacy Policy</1&gt;.","Search photos":"Search photos","Find delivery":"Find delivery","Slideshow":"Slideshow","in %{smart_count} review||||in %{smart_count} reviews":"in %{smart_count} review||||in %{smart_count} reviews","Language":"Language","more":"more","Min. 1 hour":"Min. 1 hour","Michigan":"Michigan","Cancel":"Cancel","Got a question about <strong&gt;%{businessName}</strong&gt;? Ask the Yelp community!":"Got a question about <strong&gt;%{businessName}</strong&gt;? Ask the Yelp community!","Save to a New Collection":"Save to a New Collection","Continue with email":"Continue with email","No thanks":"No thanks","Scan to get the app":"Scan to get the app","Movers":"Movers","Can you tell me more about your services?":"Can you tell me more about your services?","Oops, something went wrong. Please try again.":"Oops, something went wrong. Please try again.","Yelp":"Yelp","Get competing offers":"Get competing offers","View menu":"View menu","None of these look right? Enter your address again.":"None of these look right? Enter your address again.","Some Data By Acxiom":"Some Data By Acxiom","Login with Facebook":"Login with Facebook","Captions help others identify what's in the photo.":"Captions help others identify what's in the photo.","Hot New Businesses":"Hot New Businesses","Edit review":"Edit review","<ol&gt;\n            <li&gt;At the top of your Opera window, near the web address, you should see a <b&gt;gray location pin</b&gt;. Click it.</li&gt;\n            <li&gt;In the window that pops up, click <b&gt;Clear This Setting</b&gt;</li&gt;\n            <li&gt;You're good to go! Reload this Yelp page and try your search again.</li&gt;\n        </ol&gt;\n        <p&gt;\n            If you're still having trouble, check out <a href=\"https://help.opera.com/en/presto/control-pages/#geolocation\" target=\"_blank\"&gt;Opera's support page</a&gt;.\n            You can also search near a city, place, or address instead.\n        </p&gt;":"<ol&gt;\n            <li&gt;At the top of your Opera window, near the web address, you should see a <b&gt;gray location pin</b&gt;. Click it.</li&gt;\n            <li&gt;In the window that pops up, click <b&gt;Clear This Setting</b&gt;</li&gt;\n            <li&gt;You're good to go! Reload this Yelp page and try your search again.</li&gt;\n        </ol&gt;\n        <p&gt;\n            If ...
# <script crossorigin="anonymous" integrity="sha384-55/XQQblqJm4SZNTGqUSXYEXyn3uC9asd465hO3OeOVDl9+p31i5pM9+SO2ptV8J" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/6f3cc2b06ee6/assets/vendor/react/0.0.0-experimental-33c3af284/umd/react.production.min.js"></script>
# <script crossorigin="anonymous" integrity="sha384-mzQZgPBZXoVR01XpQQ/cDRB2PyBEnY5rOJy13hRfNTc6rj57tdoHqp0lVNW/9ke2" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/f5e755fbcb87/assets/vendor/react-dom/0.0.0-experimental-33c3af284/umd/react-dom.production.min.js"></script>
# <!-- css-middleware: body tag placeholder --><script>(function() { var e=window.yelp.critical_css;function t(t,o){var n=e.css_map[t],a=n.linkTag,i=document.querySelector('style[data-critical-css="'+t+'"]');if(i&&a&&!n.loaded){var r=function(e,t){var o=e.cloneNode();o.rel="stylesheet",o.media="all",o.href=e.href;var n=function(){this.onload=null,this.setAttribute("onload",null),t.parentNode.removeChild(t)};return o.setAttribute("onload",n),o.onload=n,o}(a,i);i.insertAdjacentElement("afterend",r),a.parentNode.removeChild(a),e.css_map[t].loaded=!0,function(t){for(var o in e.css_map)if(!e.css_map[o].loaded)return;setTimeout(t,0)}(o)}}function o(o,n){if(!e.css_map||0===Object.keys(e.css_map).length)return void setTimeout(o,0);(n?[n]:Object.keys(e.css_map)).forEach((function(n){e.lowPriorityMode?t(n,o):setTimeout(t,0,n,o)}))}e.criticalCSSReady=function(t){o(t);var n=e.recordDone.bind(window);e.recordDone=function(e,a){n.call(this,e,a),o(t,a.dataset.criticalCss)}}; })()</script>
# <script>
#         window.yelp = window.yelp || {};
#         window.yelp.zipkin_id = 'bb4c9bcce7b7eff6';
#     </script>
# <script id="yelp-js-error-reporting-init-error-reporting" type="application/json">{"config": {"release": "05dac542f04b4677a99eda4c0145e0ed64c94fc9", "metaData": {"projectName": "gondola-biz-details", "activeVersion": "0.26.0", "deploymentPreviewId": null, "zipkinTraceID": "bb4c9bcce7b7eff6"}, "environment": "prod", "blacklist": {"location": ["yl[a-z]-[a-z]*\\.js"], "type": [], "message": ["Blocked a frame with origin"]}, "sampleRate": 1}, "client": "bugsnag", "apiKey": "7a505cfcfc5a2e124a4f37054c4d684d", "enabled": true}</script>
# <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[4591,6824,5119,5188,5147,1062,9431,8022,4275,2147,8370,8471,8106,1705,9606,6048,5450,1894,8066,5903,343,4592,2176,45,1755,7854,6751]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["ClaimStatusGQL","ClaimReminderGQL","components-UnconfirmedReviewAlert","components-BizPageConfigurableAlertsGQL","OnTheMenuGQL","MapBoxV2GQL","BizHoursGQL","components-MoreBusinessInfo","components-ServiceUpdateSummaryGQL","components-BizQuestionsGQL","components-Reviews","components-ReviewFeedWarEditor","components-CollectionCardCarousel","components-RelatedBusinessesCarousel","components-SEOLinks"]}</script>
# <script async="" data-chunk="ClaimStatusGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimStatusGQL.yji-fbf19ca323848e1348ac.chunk.js"></script>
# <script async="" data-chunk="ClaimReminderGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimReminderGQL.yji-47525fc0658cd81fefb7.chunk.js"></script>
# <script async="" data-chunk="components-UnconfirmedReviewAlert" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-UnconfirmedReviewAlert.yji-ad4e4c183dfaa4581b7b.chunk.js"></script>
# <script async="" data-chunk="components-BizPageConfigurableAlertsGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/shared-css.yji-5b722b31153106c876c0.chunk.js"></script>
# <script async="" data-chunk="components-BizPageConfigurableAlertsGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizPageConfigurableAlertsGQL.yji-7dc6c399acea0fd2862b.chunk.js"></script>
# <script async="" data-chunk="OnTheMenuGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-cb5014f54829450797dfcd29560f40da8a99edbe.yji-7149f741e13024683877.js"></script>
# <script async="" data-chunk="OnTheMenuGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-ad0b283301801cf7f214ea83fabbd9f07528f1dd.yji-104ae0345873a345b63f.js"></script>
# <script async="" data-chunk="OnTheMenuGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-4a5f4db6cc3eafc9be543c179f36360785ab69fb.yji-f723b223c0ca4ce09524.js"></script>
# <script async="" data-chunk="OnTheMenuGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/shared-e55b41b68c176872ae025c8e120f2420c303617a.yji-bfe71b8c589df9336676.chunk.js"></script>
# <script async="" data-chunk="OnTheMenuGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/OnTheMenuGQL.yji-3d7222b96b7b5ccb3617.chunk.js"></script>
# <script async="" data-chunk="MapBoxV2GQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/MapBoxV2GQL.yji-2a4df75afb912e7f48f5.chunk.js"></script>
# <script async="" data-chunk="BizHoursGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/BizHoursGQL.yji-f9c4ddb36b2a9afdf083.chunk.js"></script>
# <script async="" data-chunk="components-MoreBusinessInfo" src="https://s3-media0.fl.yelpcdn.com/assets/public/shared-02d7441d86808ee81d8e462bb8dd7dfd69067068.yji-72697d9034f77d0329ec.chunk.js"></script>
# <script async="" data-chunk="components-MoreBusinessInfo" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-MoreBusinessInfo.yji-64fb18caf4c0b6c009bb.chunk.js"></script>
# <script async="" data-chunk="components-ServiceUpdateSummaryGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-ServiceUpdateSummaryGQL.yji-c0f7d8edc528d18dbc63.chunk.js"></script>
# <script async="" data-chunk="components-BizQuestionsGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizQuestionsGQL.yji-cdd3b2025975bfc18b0f.chunk.js"></script>
# <script async="" data-chunk="components-Reviews" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-79e13b707d1649f13027ae570a9e7f47cd20dd11.yji-769c346e8edb4bc24d78.js"></script>
# <script async="" data-chunk="components-Reviews" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-daf539f36f65c3a5b54d8eafb1c754c4727b9957.yji-42ec7f9d6070ffcf0b0d.js"></script>
# <script async="" data-chunk="components-Reviews" src="https://s3-media0.fl.yelpcdn.com/assets/public/shared
js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-4279492554d69ae946d1a5167ab09b75a026e755.yji-e0dd1faca65c07360506.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-a30c3a63f0c86ab2736ddcc52e59a126e39aa009.yji-fe8d2b20f2638d53bb3f.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-94d0c717e10926ac9b746a367106afa227fc6c1c.yji-6d7677a461711b4753a9.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-a61940be62ce3b2e0fdcfb496277a5f00ece9bbf.yji-ae35dd2066118af9f67b.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-e7e4fb2ca5dd99da5fef4e2f639c04ac10a0c102.yji-0aba71f99aa552010dd0.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-cc78013fbf1f5e4702060cb3ce7cc3ceb3d99e04.yji-9c7b114be0936d9001f6.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-6e4cfec1bdc3ca36c5edf5bb9e89dbd0bc042e31.yji-381636e7e7ebad038804.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-144d1e9a4c4b39dbd37edbf0c454b0c5d147d947.yji-db38c2c33977d35b282c.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-87de765b9b84b2509b5aab2f3e7fa3d9619ce2fa.yji-906b36dec1c8dd048843.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-db8d2e66ff7de1f41b54712ab57306f3b14831c5.yji-a73fbb1aed7a6f342e65.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-c53db7287808c63ba8add8a2c9467cb5490ad364.yji-8bcaba51708b3c48fa06.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-243c9a2f13092662200f240f8ce4fcacebc60406.yji-d94a5864a168b695d362.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-9e3b0816aca2d6feaae995b007bac371ff9cf16a.yji-918046354a56bb53e845.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-32f23b5a7e246666489f418c8f401e0f7d91ba23.yji-4864cf84c7873b95e8ff.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-517f09ffa454b877f1d19433ac56582c832ce3d8.yji-18e0d5a9140942a19b4e.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-91cc20c011180b4d9c2e412b5258e21dcb9d3ea0.yji-0a6e69df22a6b256e1e6.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-866f173606dfafc95254741ed72dec920384fc4c.yji-c0179019f9327cb14b52.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-172a68520fbf4f5eca3a9e03ab7457e4c3766442.yji-669737483ffe7ceb6808.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-da7f1448b29830c736ded37084954a3587c3e490.yji-13fb50cb3e3686373184.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-26600fb9beeb8bdb676c08d06ed9875b2329bd8b.yji-f2bb90611eb3cacec0da.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-c0faa51540bcf5d815ceff9d6aa8334a4e9054f8.yji-466373ec3c6bae803776.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_gondola-biz-details.yji-1a0204fbe0031e336d44.js"></script>
# <script>
#             window.yelp = window.yelp || {};
#             window.yelp.cookieTypePreferencesHeader = '["ANALYTICS","FUNCTIONAL","INTERNAL","STRICTLY_NECESSARY","TARGETING"]';
#
#             function addCookieManagementScript() {
#                 var tag = document.createElement('script');
#                 tag.async = true;
#                 tag.src = 'https://cdn.cookielaw.org/scripttemplates/otSDKStub.js';
#                 tag.type = 'text/javascript';
#                 tag.charset = 'UTF-8';
#                 tag.setAttribute('data-domain-script', '5fbcd417-fbc1-4fcc-abad-f622f1bba72d');
#                 tag.setAttribute('data-document-language', 'true');
#
#                 document.head.appendChild(tag);
#             }
#
#             if ('requestIdleCallback' in window) {
#                 requestIdleCallback(addCookieManagementScript, { timeout: 4000 });
#             } else {
#                 setTimeout(addCookieManagementScript, 2000);
#             }
#         </script><script type="text/javascript">window.yelp.initReactComponents();</script></body></html>

# %%
results
# Out:
# [<p class="comment__09f24__gu0rG css-1sufhje"><span class=" raw__09f24__T4Ezm" lang="en">These pancakes are delicious! <br/><br/>I had blueberry and chocolate chip pancakes with a fruit cup and it was delicious!<br/><br/>I will want to eat there everyday.<br/><br/>From L.W. 7 years old</span></p>,
the long run. We picked at them and they were definitely warm, gooey, and sweet. They were soon gobbled up. When it came time to order our meal, I decided on one of "Farmer White\'s Favorites" which were "served with red bliss home fries." I chose the Uncle Cricket\'s, "choice of pancakes or french toast, with homemade corned beef hash, topped with two eggs ($8.99). I got mine with French Toast. The other ladies ordered similar meals from the menu. When our server took our order, she asked if we wanted "real maple syrup with our food," noting that it was a $1.99 surcharge for "real maple syrup." I was a little put off by this. Why call it maple syrup if it\'s that Aunt Jemima junk? This is a breakfast place in New England.... why would they serve anything BUT maple syrup? But I digress... The server also asked how we wanted our home fries. (imagine, again, the sound of a record needle screeching across the vinyl here... this was \'red flag #2\' and I completely missed it) She went on to list a number of additions to the homefries, peppers, onions, garlic, mushrooms, jalapenos, tomato, broccoli. "Sure!" I said, "Load them up!" (what an idiot I am, but this was not to be realized until an hour had passed). We had a wonderful time catching up on news about grandchildren, pets, illnesses, and impending weddings.Our food was brought to us within a reasonable amount of time and everything was delicious. I would say that the food was a cut above typical breakfast fare in freshness, variety, and taste. The food was outstanding.Our server came around for another refill of coffee and asked if we wanted our checks. One of our friends insisted on getting two muffins ($2.09) to go, exclaiming that The Farmer\'s Kitchen has the best muffins ever! When our server brought our checks, I noticed that she had charged me with the cinnamon rolls and muffins, in addition to my breakfast meal. I also noticed that every addition to the "red bliss home fries" bore their own charge. ...sigh... The friend who ordered the muffins noticed that they were not on her bill. I told her they were on my bill, and not wanting to be a dick about it, I told her not to worry I would get them for her. Of course she tried to give me $5, but like a good friend, I refused. When considering the bill as a whole, the two muffins were only part of the story that led to my disappointment in The Farmer\'s Kitchen and in myself.Coffee 2.29Cinnamon buns 7.98Uncle Cricket\'s 8.99Peppers .79Onions .79Garlic .79Mushrooms .79Jalapenos .79Tomato .79Broccoli .79Real maple syrup 1.99Muffins 4.18Tax (9%) 2.78Tip 5.00_________Total: $ 35+ for breakfast. I felt absolutely swindled. I do accept that this was somewhat my own fault for not asking for more details from our serv ...

# %%
results[2].text
# Out:
# 'Delicious ! Had the homemade hash and eggs. Large portions, perfectly cooked. Comes with side of home fries and either pancakes or French toast.Garden omelette was also delicious!'

# %% [markdown]
# # Load Reviews into DataFrame and Score

# %%
df = pd.DataFrame(np.array(reviews),columns=["review"])

# %%
df.head()
# Out:
#                                               review
# 0  These pancakes are delicious! I had blueberry ...
# 1  Ordered recently from them the first time. Got...
# 2  Delicious ! Had the homemade hash and eggs. La...
# 3  Used to be one of our favorites for years....t...
# 4  I dont think I've ever hurt myself on breakfas...

# %%
def sentiment_score(review):
  tokens = tokenizer.encode(review,return_tensors='pt')
  result = model(tokens)
  return int(torch.argmax(result.logits))+1

# %%
sentiment_score(df['review'].iloc[3])
# Out:
# 3

# %%
#since our NLP pipeline is restricted to some limit of max tokens (here : 512)

df['sentiment'] = df['review'].apply(lambda x:sentiment_score(x[:512]))

# %%
df.head()
# Out:
#                                               review  sentiment
# 0  These pancakes are delicious! I had blueberry ...          5
# 1  Ordered recently from them the first time. Got...          1
# 2  Delicious ! Had the homemade hash and eggs. La...          5
# 3  Used to be one of our favorites for years....t...          3
# 4  I dont think I've ever hurt myself on breakfas...          4
